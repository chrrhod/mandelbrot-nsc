# %% [markdown]
# # M1

# %% [markdown]
# ![image.png](mp3_m1_output.png)

# %% [markdown]
# Divergence Fraction:
#
# Number of points that did not diverge within 1000 iterations: 0
#
# Early Divergence Location:
#
# Earliest divergence at index: (np.int64(461), np.int64(25)), C = (-0.7528043052837573+0.10260861056751468j)
#
#
# Correlation: High divergence iteration count has a very high visual correlation with high escape iteration.

# %% [markdown]
# ![image.png](mp3_m2_output.png)

# %% [markdown]
# Max K value:
#
# Max kappa at index (np.int64(127), np.int64(486)), C = (-0.7491956947162427+0.09999412915851272j), kappa = 5.63e+07. Visually it looks like it could match, but the print statement proves it wrong.
#
#
# What is κ for interior pixels (n = max iter)?:
#
# I dont know as there is no interior pixels

# %% [markdown]
# # Section 2

# %% [raw]
# L9 M1:
#
# -m pytest -v
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.14, pytest-9.0.2, pluggy-1.5.0 -- /Users/rhod/mamba/envs/optimization/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/rhod/Library/CloudStorage/OneDrive-AalborgUniversitet/Semestre/p8/Numerical_Scientific_Computing/mandelbrot-nsc
# collected 11 items
#
# test_mandelbrot.py::test_mandelbrot_pixel_python_analytic[0.0-0.0-50-50] PASSED [  9%]
# test_mandelbrot.py::test_mandelbrot_pixel_python_analytic[3.0-0.0-50-1] PASSED [ 18%]
# test_mandelbrot.py::test_mandelbrot_pixel_python_analytic[1.0-0.0-50-3] PASSED [ 27%]
# test_mandelbrot.py::test_mandelbrot_pixel_numba_matches_python[0.0-0.0-50] PASSED [ 36%]
# test_mandelbrot.py::test_mandelbrot_pixel_numba_matches_python[3.0-0.0-50] PASSED [ 45%]
# test_mandelbrot.py::test_mandelbrot_pixel_numba_matches_python[1.0-0.0-50] PASSED [ 54%]
# test_mandelbrot.py::test_mandelbrot_pixel_numba_matches_python[-0.75-0.1-80] PASSED [ 63%]
# test_mandelbrot.py::test_numpy_matches_naive_small_grid PASSED           [ 72%]
# test_mandelbrot.py::test_worker_matches_chunk_output PASSED              [ 81%]
# test_mandelbrot.py::test_parallel_matches_serial_small_grid PASSED       [ 90%]
# test_mandelbrot.py::test_dask_submit_gather_matches_expected_chunk PASSED [100%]
#
# ============================== 11 passed in 2.32s ==============================

# %% [raw]
# -m pytest --cov=. -v
# ============================================= test session starts ==============================================
# platform darwin -- Python 3.11.14, pytest-9.0.2, pluggy-1.5.0 -- /Users/rhod/mamba/envs/optimization/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/rhod/Library/CloudStorage/OneDrive-AalborgUniversitet/Semestre/p8/Numerical_Scientific_Computing/mandelbrot-nsc
# plugins: cov-7.1.0
# collected 11 items
#
# test_mandelbrot.py::test_mandelbrot_pixel_python_analytic[0.0-0.0-50-50] PASSED                          [  9%]
# test_mandelbrot.py::test_mandelbrot_pixel_python_analytic[3.0-0.0-50-1] PASSED                           [ 18%]
# test_mandelbrot.py::test_mandelbrot_pixel_python_analytic[1.0-0.0-50-3] PASSED                           [ 27%]
# test_mandelbrot.py::test_mandelbrot_pixel_numba_matches_python[0.0-0.0-50] PASSED                        [ 36%]
# test_mandelbrot.py::test_mandelbrot_pixel_numba_matches_python[3.0-0.0-50] PASSED                        [ 45%]
# test_mandelbrot.py::test_mandelbrot_pixel_numba_matches_python[1.0-0.0-50] PASSED                        [ 54%]
# test_mandelbrot.py::test_mandelbrot_pixel_numba_matches_python[-0.75-0.1-80] PASSED                      [ 63%]
# test_mandelbrot.py::test_numpy_matches_naive_small_grid PASSED                                           [ 72%]
# test_mandelbrot.py::test_worker_matches_chunk_output PASSED                                              [ 81%]
# test_mandelbrot.py::test_parallel_matches_serial_small_grid PASSED                                       [ 90%]
# test_mandelbrot.py::test_dask_submit_gather_matches_expected_chunk PASSED                                [100%]
#
# ================================================ tests coverage ================================================
# ______________________________ coverage: platform darwin, python 3.11.14-final-0 _______________________________
#
# Name                 Stmts   Miss  Cover
# ----------------------------------------
# Lecture8M1.py           41     41     0%
# Lecture8M2.py           39     39     0%
# mandelbrot.py          150     86    43%
# mandelbrot_dask.py     116     98    16%
# test_mandelbrot.py      46      0   100%
# ----------------------------------------
# TOTAL                  392    264    33%
# ============================================== 11 passed in 2.56s ==============================================

# %% [markdown]
# # Section 3

# %% [raw]
# Device: Apple M2 Pro
#
# Benchmarking N=1024, max_iter=100, 10 runs each:
#
#   float32: 2.7 ms
#   Apple M2 Pro does not support float64 (cl_khr_fp64 missing).

# %% [raw]
# Device: Apple M2 Pro
#
# Benchmarking N=4096, max_iter=100, 10 runs each:
#
#   float32: 20.6 ms
#   Apple M2 Pro does not support float64 (cl_khr_fp64 missing).
#
# Saved to mandelbrot_opencl.png

# %% [raw]
# Device: Apple M2 Pro
#
# Benchmarking N=8192, max_iter=100, 10 runs each:
#
#   float32: 48.7 ms
#   Apple M2 Pro does not support float64 (cl_khr_fp64 missing).
#
# Saved to mandelbrot_opencl.png

# %% [markdown]
# N = 1024
#
# ![image.png](attachment:image.png)

# %% [markdown]
# N = 4096
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Not suprising that the GPU is so much faster for this task
