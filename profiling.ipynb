# %%
import cProfile , pstats
from mandelbrot import mandelbrot_naive, mandelbrot_numpy



xmin, xmax, ymin, ymax = -2.0, 1.0, -1.5, 1.5
width, height = 1024, 1024
max_iter = 100


cProfile.run('mandelbrot_naive(xmin, xmax, ymin, ymax, width, height, max_iter)','naive_profile.prof')
cProfile.run('mandelbrot_numpy(xmin, xmax, ymin, ymax, width, height, max_iter)','numpy_profile.prof')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 import cProfile , pstats
# ----> 2 from mandelbrot import mandelbrot_naive, mandelbrot_numpy
#       6 xmin, xmax, ymin, ymax = -2.0, 1.0, -1.5, 1.5
#       7 width, height = 1024, 1024
#
# ImportError: cannot import name 'mandelbrot_naive' from 'mandelbrot' (/Users/rhod/Library/CloudStorage/OneDrive-AalborgUniversitet/Semestre/p8/Numerical_Scientific_Computing/mandelbrot-nsc/mandelbrot.py)

# %%
stats = pstats.Stats('naive_profile.prof')
stats.sort_stats('cumulative')
stats.print_stats(10)
# Out:
# Thu Feb 26 13:31:10 2026    naive_profile.prof
#
#          23008341 function calls in 3.330 seconds
#
#    Ordered by: cumulative time
#    List reduced from 20 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    3.330    3.330 {built-in method builtins.exec}
#         1    0.001    0.001    3.330    3.330 <string>:1(<module>)
#         1    0.330    0.330    3.330    3.330 /Users/rhod/Library/CloudStorage/OneDrive-AalborgUniversitet/Semestre/p8/Numerical_Scientific_Computing/mandelbrot-nsc/mandelbrot.py:43(compute_mandelbrot)
#   1048576    2.315    0.000    2.998    0.000 /Users/rhod/Library/CloudStorage/OneDrive-AalborgUniversitet/Semestre/p8/Numerical_Scientific_Computing/mandelbrot-nsc/mandelbrot.py:35(mandelbrot_point)
#  21959734    0.682    0.000    0.682    0.000 {built-in method builtins.abs}
#         1    0.001    0.001    0.001    0.001 {built-in method numpy.zeros}
# ...

# %%
stats = pstats.Stats('numpy_profile.prof')
stats.sort_stats('cumulative')
stats.print_stats(10)
# Out:
# Thu Feb 26 13:31:11 2026    numpy_profile.prof
#
#          78 function calls in 0.658 seconds
#
#    Ordered by: cumulative time
#    List reduced from 42 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.658    0.658 {built-in method builtins.exec}
#         1    0.002    0.002    0.658    0.658 <string>:1(<module>)
#         1    0.653    0.653    0.656    0.656 /Users/rhod/Library/CloudStorage/OneDrive-AalborgUniversitet/Semestre/p8/Numerical_Scientific_Computing/mandelbrot-nsc/mandelbrot.py:83(compute_mandelbrot)
#         1    0.000    0.000    0.002    0.002 /Users/rhod/mamba/envs/optimization/lib/python3.11/site-packages/numpy/lib/_function_base_impl.py:5134(meshgrid)
#         3    0.000    0.000    0.001    0.000 /Users/rhod/mamba/envs/optimization/lib/python3.11/site-packages/numpy/lib/_function_base_impl.py:5280(<genexpr>)
# ...
