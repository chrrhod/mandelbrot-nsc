# %%
import cProfile , pstats
from mandelbrot import NaiveMandelbrot , NumpyMandelbrot



xmin, xmax, ymin, ymax = -2.0, 1.0, -1.5, 1.5
width, height = 1024, 1024
max_iter = 100

Naive_version = NaiveMandelbrot(xmin, xmax, ymin, ymax, width, height, max_iter)
        #naive_t, naive_M = benchmark(Naive.compute_mandelbrot)

Numpy_version = NumpyMandelbrot(xmin, xmax, ymin, ymax, width, height, max_iter)


cProfile.run('Naive_version.compute_mandelbrot()','naive_profile.prof')
cProfile.run('Numpy_version.compute_mandelbrot()','numpy_profile.prof')
# Out:
# Thu Feb 26 13:29:52 2026    naive_profile.prof
#
#          23008341 function calls in 3.307 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    3.307    3.307 {built-in method builtins.exec}
#         1    0.000    0.000    3.307    3.307 <string>:1(<module>)
#         1    0.330    0.330    3.306    3.306 /Users/rhod/Library/CloudStorage/OneDrive-AalborgUniversitet/Semestre/p8/Numerical_Scientific_Computing/mandelbrot-nsc/mandelbrot.py:43(compute_mandelbrot)
#   1048576    2.279    0.000    2.974    0.000 /Users/rhod/Library/CloudStorage/OneDrive-AalborgUniversitet/Semestre/p8/Numerical_Scientific_Computing/mandelbrot-nsc/mandelbrot.py:35(mandelbrot_point)
#  21959734    0.695    0.000    0.695    0.000 {built-in method builtins.abs}
#         1    0.001    0.001    0.001    0.001 {built-in method numpy.zeros}
# ...

# %%
stats = pstats.Stats('naive_profile.prof')
stats.sort_stats('cumulative')
stats.print_stats(10)

# %%
stats = pstats.Stats('numpy_profile.prof')
stats.sort_stats('cumulative')
stats.print_stats(10)
